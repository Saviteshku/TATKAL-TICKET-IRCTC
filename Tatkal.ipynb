# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

#Path = "C:\\webAutomation\\chromedriver.exe"

caps = DesiredCapabilities().CHROME
#caps["pageLoadStrategy"] = "normal"  #  complete web page load
caps["pageLoadStrategy"] = "eager"  #  interactive web page load
#caps["pageLoadStrategy"] = "none"
driver = webdriver.Chrome(desired_capabilities=caps, executable_path=r'C:\webAutomation\chromedriver.exe')

#driver = webdriver.Chrome(Path)
driver.get('https://www.irctc.co.in/nget/train-search')
driver.maximize_window()
sleep(8)

ok_field = driver.find_element_by_xpath('/html/body/app-root/app-home/div[1]/app-header/p-dialog[2]/div/div/div[2]/div/form/div[2]/button')
ok_field.click();
sleep(2)

from_field = driver.find_element_by_xpath('/html/body/app-root/app-home/div[1]/app-header/div[2]/div[2]/div[1]/a[1]')
from_field.click()
sleep(1)
#enter username and password----------------------------------------------------------------------

user_field = driver.find_element_by_xpath('//*[@id="userId"]')
user_field.send_keys("USERNAME")

pswrd_field = driver.find_element_by_xpath('//*[@id="pwd"]')
pswrd_field.send_keys("PASSWORD")
sleep(8)

login_field = driver.find_element_by_xpath('//*[@id="login_header_disable"]/div/div/div[2]/div[2]/div/div[2]/div[2]/div[2]/form/span/button')
login_field.click()
sleep(3)


#turn this on if already made a booking
close_field = driver.find_element_by_xpath('//*[@id="last_txn_header"]/div/div/div[3]/p-footer/div[1]/button')
close_field.click()

#forms------------------------------------------------------------------------------------------------
from_field = driver.find_element_by_xpath('//*[@id="origin"]/span/input')
from_field.send_keys("AMBALA CANT JN - UMB")

to_field = driver.find_element_by_xpath('//*[@id="destination"]/span/input')
to_field.send_keys("GORAKHPUR JN - GKP")
sleep(1)
to_field.send_keys(Keys.TAB)

#//*[@id="jDate"]/span/div/div/div[2]/table/tbody/tr[5]/td[7]/a
date_field = driver.find_element_by_xpath('//*[@id="jDate"]/span/div/div/div[2]/table/tbody/tr[6]/td[1]/a')
date_field.click()

find_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-main-page/div/div/div[1]/div[2]/div[1]/app-jp-input/div/form/div[5]/div/button')
find_field.click()
sleep(10)

#modify search-------------------------------------------------------------------------------
#class_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-train-list/div[2]/app-modify-search/div/form/div[2]/div[1]/div[4]/p-dropdown/div/div[3]')
#class_field.click()

quota_field = driver.find_element_by_xpath('//*[@id="journeyQuota"]/div/div[3]')
quota_field.click()

#select quota = tatkal
squota_field = driver.find_element_by_xpath('//*[@id="journeyQuota"]/div/div[4]/div/ul/p-dropdownitem[5]/li')
squota_field.click()

modify_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-train-list/div[2]/app-modify-search/div/form/div[3]/button[1]')
modify_field.click()
sleep(3)


#Select departure time-------------------------------------------------------------------------
#0:00 to 6:00 AM (morning)
d1time_field = driver.find_element_by_xpath('//*[@id="ui-panel-14-content"]/div/table/tr/strong/td[1]')
d1time_field.click()

#6:00AM to 12: PM (morning)
d2time_field = driver.find_element_by_xpath('//*[@id="ui-panel-14-content"]/div/table/tr/strong/td[2]')
d2time_field.click()

#12:00PM to 18:00 PM (evening)
#d3time_field = driver.find_element_by_xpath('//*[@id="ui-panel-14-content"]/div/table/tr/strong/td[3]')
#d3time_field.click()

#18:00PM to 24:00 PM (evening)
d4time_field = driver.find_element_by_xpath('//*[@id="ui-panel-14-content"]/div/table/tr/strong/td[4]')
d4time_field.click()

#select final class-----------------------------------------------------------------------------
#sleeper = //*[@id="divMain"]/div/app-train-list/div[4]/div/div[5]/div/div[1]/app-train-avl-enq/div[1]/div[5]/div/table/tr/td[2]/div
#AC 2A = //*[@id="divMain"]/div/app-train-list/div[4]/div/div[5]/div/div[1]/app-train-avl-enq/div[1]/div[5]/div/table/tr/td[4]/div
#AC 3A = //*[@id="divMain"]/div/app-train-list/div[4]/div/div[5]/div/div[1]/app-train-avl-enq/div[1]/div[5]/div/table/tr/td[3]/div
sfclass_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-train-list/div[4]/div/div[5]/div[2]/div[1]/app-train-avl-enq/div[1]/div[5]/div/table/tr/td[2]/div')
sfclass_field.click()

#click on book and agree
book_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-train-list/div[4]/div/div[5]/div[2]/div[1]/app-train-avl-enq/div[2]/div/span/span/button[1]')
book_field.click()


agree_field = driver.find_element_by_xpath('//*[@id="divMain"]/div/app-train-list/p-confirmdialog[1]/div/div/div[3]/button[1]/span[2]')
agree_field.click()
sleep(3)


#enter passanger details--------------------------------------------------------------------------
#name
p1name_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[1]/p-autocomplete/span/input')
p1name_field.send_keys("TRAVELLER1")
p1name_field.send_keys(Keys.TAB)

#age
p1age_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[2]/input')
p1age_field.send_keys("23")
p1age_field.send_keys(Keys.TAB)

#gender
p1gender_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select')
p1gender_field.click()

#male = //*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select/option[2]
p1genders_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select/option[3]')
p1genders_field.click()

#country
p1country_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[4]/select')
p1country_field.click()

p1countrys_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[4]/select/option[106]')
p1countrys_field.click()

#seat selection
p1seat_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/div[1]/select')
p1seat_field.click()

p1seats_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/div[1]/select/option[5]')
p1seats_field.click()

#add new passenger----------------------------------------------------------------------------------------
add_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[1]/a/span')
add_field.click()

#2nd passanger details
#name
p2name_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[1]/p-autocomplete/span/input')
p2name_field.send_keys("TRAVELLER2")
p2name_field.send_keys(Keys.TAB)

#age
p2age_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[2]/input')
p2age_field.send_keys("27")
p2age_field.send_keys(Keys.TAB)

#gender
p2gender_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select')
p2gender_field.click()

#male = //*[@id="ui-panel-24-content"]/div/div[1]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select/option[2]
#female = //*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select/option[3]
p2genders_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[3]/select/option[3]')
p2genders_field.click()

#country
p2country_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[4]/select')
p2country_field.click()

p2countrys_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/span/div[4]/select/option[106]')
p2countrys_field.click()

#seat selection
p2seat_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/div[1]/select')
p2seat_field.click()

p2seats_field = driver.find_element_by_xpath('//*[@id="ui-panel-24-content"]/div/div[2]/div[2]/div/app-passenger/div/div[1]/div[1]/select/option[4]')
p2seats_field.click()

#additional forms--------------------------------------------------------------------------------------------
mobile_field = driver.find_element_by_xpath('//*[@id="mobileNumber"]')
mobile_field.send_keys("MOBILE NUMBER")

address1_field = driver.find_element_by_xpath('//*[@id="aaa1"]')
address1_field.send_keys("ADDRESS")

pin_field = driver.find_element_by_xpath('//*[@id="aaa4"]')
pin_field.send_keys("PINCODE")
pin_field.send_keys(Keys.TAB)
#pin_field.send_keys(Keys.TAB)

#state_field = driver.find_element_by_xpath('//*[@id="aaa4"]')
#state_field.send_keys("Bihar")

#country_field = driver.find_element_by_xpath('//*[@id="aaa4"]')
#country_field.send_keys("804408")

sleep(2)

post_field = driver.find_element_by_xpath('//*[@id="ui-panel-27-content"]/div/app-address-capture/div/div[7]')
post_field.click()

post1_field = driver.find_element_by_xpath('//*[@id="address-postOffice"]/option[6]')
post1_field.click()
sleep(3)

#select payment methods---------------------------------------------------------------------------------------
pay_field = driver.find_element_by_xpath('//*[@id="3"]/div/div[2]')
pay_field.click()

conti1_field = driver.find_element_by_xpath('//*[@id="psgn-form"]/form/div/div[1]/div[16]/div/button[2]')
conti1_field.click()
sleep(55)

#enter captcha
conti2_field = driver.find_element_by_xpath('//*[@id="review"]/div[1]/form/div[3]/div/button[2]')
conti2_field.click()
sleep(2)

#slelect payment options----------------------------------------------------------------------------------------
upi_field = driver.find_element_by_xpath('//*[@id="pay-type"]/span/div[1]')
upi_field.click()
sleep(2)

card_field = driver.find_element_by_xpath('//*[@id="pay-type"]/span/div[4]')
card_field.click()

book_field = driver.find_element_by_xpath('//*[@id="bank-type"]/div/table/tr/span[1]/td/div/div')
book_field.click()
sleep(2)

pay_field = driver.find_element_by_xpath('//*[@id="psgn-form"]/div[1]/div[1]/app-payment/div[2]/button[2]')
pay_field.click()
sleep(5)

#navitage to payment page---------------------------------------------------------------------------------------
pays_field = driver.find_element_by_xpath('//*[@id="stage"]/ul/li')
pays_field.click()
sleep(2)

pays1_field = driver.find_element_by_xpath('//*[@id="other_debit"]')
pays1_field.click()

cardno_field = driver.find_element_by_xpath('//*[@id="card_no"]')
cardno_field.send_keys("CARD NUMBER")

cardname_field = driver.find_element_by_xpath('//*[@id="name"]')
cardname_field.send_keys("NAME ON CARD")

cardexp_field = driver.find_element_by_xpath('//*[@id="expMonthSelect"]')
cardexp_field.click()

cardexp1_field = driver.find_element_by_xpath('//*[@id="expMonthSelect"]/option[7]')
cardexp1_field.click()

cardexp2_field = driver.find_element_by_xpath('//*[@id="expYearSelect"]')
cardexp2_field.click()

cardexp3_field = driver.find_element_by_xpath('//*[@id="expYearSelect"]/option[7]')
cardexp3_field.click()

cardexp4_field = driver.find_element_by_xpath('//*[@id="other_debit_cvv_no"]')
cardexp4_field.send_keys("CVV")
sleep(6)

payfinal_field = driver.find_element_by_xpath('//*[@id="submit_btn"]')
payfinal_field.click()



#driver.quit()   #to close window
